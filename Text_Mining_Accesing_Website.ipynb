# %% [markdown]
# <a href="https://colab.research.google.com/github/NaHyeon1Kim/Modeling/blob/main/Text_Mining_Accesing_Website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. requests를 이용한 웹 접속

# %%
# !pip install requests

# %%
import requests
res = requests.get('http://www.naver.com')
res.status_code

#get : 서버로부터 정보를 요청하는 HTTP 요청 메소드
#400
# Out:
# 200

# %%
import requests
res = requests.get("http://naver.com")
res.text

#네이버 홈페이지의 HTML 코드를 출력
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description
# ...

# %% [markdown]
# 2. 웹 문서 Parsing

# %%
# !pip install beautifulsoup4

#parsing을 위한 라이브러리
#문서나 데이터를 의미 있는 단위로 분해하고 해석하는 과정
#즉, 컴퓨터가 이해할 수 있는 형태로 변환

# %%
import requests
from bs4 import BeautifulSoup

url = "http://naver.com"
res = requests.get(url)
res.text
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description
# ...

# %%
soup = BeautifulSoup(res.text, "html.parser")
soup
# Out:
#  <!DOCTYPE html>
# ...

# %%
soup.head.title
# Out:
# <title>NAVER</title>

# %% [markdown]
# 3. API 이용 웹 수집

# %%
# !pip install -U pykrx
#API를 좀 더 전문화된 데이터로 제공해주는 방식
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 27.5 MB/s eta 0:00:00
# ...

# %%
#pykrx 라이브러리 사용하여 한국거래소(KRX)의 주식 데이터 가져오기
#ticker : 종목
from pykrx import stock

tickers = stock.get_market_ticker_list("20231001")
tickers

stock1 = stock.get_market_ticker_name("010620")
stock1

df = stock.get_market_ohlcv_by_date("20230901","20231001","010620")
df.head(5)
# Out:
#                시가     고가     저가     종가     거래량       등락률
# 날짜
# 2023-09-01  91000  91800  88400  88400  140629 -2.857143
# 2023-09-04  88800  90200  88000  89100  130402  0.791855
# 2023-09-05  89300  89800  87100  87200  132201 -2.132435
# 2023-09-06  87200  89700  87100  87800  149253  0.688073
# 2023-09-07  87700  88200  86900  87500  110590 -0.341686

# %%
df = stock.get_market_ohlcv_by_date("20210104", "20210108", "005930", "d")
df

df = stock.get_market_ohlcv_by_date("20201104", "20210108", "005930", "m")
df
# Out:
#                시가     고가     저가     종가        거래량
# 날짜
# 2020-11-30  58900  69500  57800  66700  460991347
# 2020-12-31  67100  81300  67100  81000  529998852
# 2021-01-31  81000  90000  80200  88800  207737907
